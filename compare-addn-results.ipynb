# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
results = {
    'cite': {
        'baseline': [0.8964356826004278, 0.8962572442533452, 0.8951644868952094, 0.8956385590808086, 0.8963762545466774],
        'addn-comp-10': [0.8965701007439538, 0.8964323140903845, 0.8952840356216628, 0.8958435058929023, 0.8965631137487572],
        'addn-comp-20': [0.8965943054718688, 0.8965177612821783, 0.8953343450879847, 0.8958509178184094, 0.8965795232739098],
        'addn-comp-30': [0.8966761234236916, 0.8964949113449119, 0.8953510346182348, 0.8959204645567372, 0.8965882551766322],
    },
    'multiome': {
        'baseline': [0.6671101725819112, 0.666725453293118, 0.6671487545580479, 0.6672732132704189, 0.6672083935673123],
        'addn-comp-10': [0.6685133256904977, 0.6680985084883903, 0.6685453572716432, 0.6686461419463673, 0.6685515615696742],
        'addn-comp-20': [0.6685390516708978, 0.6681384047081338, 0.6685627976975622, 0.6686858785414962, 0.668589316849896],
        'addn-comp-30': [0.6685688163984351, 0.6681455933478534, 0.6685752458816252, 0.6686973038003132, 0.6686190765063739],
    }
}

# %%
modality = 'multiome'

# %%
avg = []
names = ['baseline', 'addn-comp-10', 'addn-comp-20', 'addn-comp-30']
for k in names:
    avg.append(np.mean(results[modality][k]))

# %%
plt.plot(names, avg)
plt.ylabel('Average over \n5-fold random CV\n Pearson Correlation Score', rotation=0, labelpad=80)
plt.xlabel('Experiment adding different length context vectors')
plt.xticks(fontsize=9)
plt.yticks(fontsize=9)
plt.title(f'Prediction on {modality} with context vector addition')
# Out:
# Text(0.5, 1.0, 'Prediction on multiome with context vector addition')
